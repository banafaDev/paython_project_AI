# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install panda

# %%
file = 'C:\\Users\\user\\OneDrive - King Abdullaziz University\\Desktop\\Dev\\AI\\data.csv'
df = pd.read_csv(file, encoding='latin1')
df = pd.DataFrame(df)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df = df.drop('CustomerID',axis=1)

# %%
num_col = df.select_dtypes(include=["number"]).columns.tolist()
cat_col = df.select_dtypes(include=["object"]).columns.tolist()
print(cat_col)
print(num_col)
for col in cat_col:
    mode_value = df[col].mode()[0]
    df[col].fillna(mode_value,inplace=True)

for col in num_col:
    df[col].fillna(df[col].mean(),inplace=True)
# Out:
# ['InvoiceNo', 'StockCode', 'Description', 'InvoiceDate', 'Country']
# ['Quantity', 'UnitPrice']

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice         Country
# ...

# %%
duplicate_rows = df.duplicated()
duplicate_rows.sum()
# Out:
# 5268

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice         Country
# ...

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice         Country
# ...

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice
# count  536641.000000                         536641  536641.000000
# mean        9.620029  2011-07-04 08:57:06.087421952       4.632656
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 10:52:00       1.250000
# 50%         3.000000            2011-07-19 14:04:00       2.080000
# 75%        10.000000            2011-10-18 17:05:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       219.130156                            NaN      97.233118

# %%
df.describe(include=['object'])
# Out:
#        InvoiceNo StockCode                         Description         Country
# count     536641    536641                              536641          536641
# unique     25900      4070                                4223              38
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER  United Kingdom
# freq        1114      2301                                3811          490300

# %%
df['Country'].value_counts(normalize=True) * 100
# Out:
# Country
# United Kingdom          91.364618
# Germany                  1.766544
# France                   1.591567
# EIRE                     1.525042
# Spain                    0.471078
# Netherlands              0.441822
# Belgium                  0.385546
# Switzerland              0.371571
# Portugal                 0.281380
# Australia                0.234421
# Norway                   0.202370
# Italy                    0.149634
# Channel Islands          0.141063
# Finland                  0.129509
# Cyprus                   0.113856
# Sweden                   0.085905
# Unspecified              0.082364
# Austria                  0.074724
# Denmark                  0.072488
# Japan                    0.066711
# Poland                   0.063543
# Israel                   0.054785
# USA                      0.054226
# Hong Kong                0.052922
# Singapore                0.042673
# Iceland                  0.033915
# Canada                   0.028138
# ...

# %%
df['Description'].value_counts(normalize=True) * 100
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER     0.710158
# REGENCY CAKESTAND 3 TIER               0.407908
# JUMBO BAG RED RETROSPOT                0.401758
# PARTY BUNTING                          0.320512
# LUNCH BAG RED RETROSPOT                0.302810
#                                          ...
# rcvd be air temp fix for dotcom sit    0.000186
# SET 12 COLOURING PENCILS DOILEY        0.000186
# SET 36 COLOURING PENCILS DOILEY        0.000186
#  I LOVE LONDON MINI RUCKSACK           0.000186
# found some more on shelf               0.000186
# Name: proportion, Length: 4223, dtype: float64

# %%
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month

year_counts = df['Year'].value_counts(normalize=True) * 100
month_counts = df['Month'].value_counts(normalize=True) * 100
df = df.drop(['Day', 'Hour'], axis=1, errors='ignore')
print("Transactions per Year:\n", year_counts)
print("")
print("\nTransactions per Month:\n", month_counts)
# Out:
# Transactions per Year:
#  Year
# 2011    92.177079
# 2010     7.822921
# Name: proportion, dtype: float64
#
#
# Transactions per Month:
#  Month
# 11    15.530494
# 12    12.527369
# 10    11.174882
# 9      9.291314
# 7      7.317182
# 5      6.854117
# 6      6.821879
# 3      6.790201
# 8      6.533977
# 1      6.503417
# 4      5.534613
# 2      5.120555
# Name: proportion, dtype: float64

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice         Country  Year  Month
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice         Country  Year  Month
# 0 2010-12-01 08:26:00       2.55  United Kingdom  2010     12
# 1 2010-12-01 08:26:00       3.39  United Kingdom  2010     12
# 2 2010-12-01 08:26:00       2.75  United Kingdom  2010     12
# 3 2010-12-01 08:26:00       3.39  United Kingdom  2010     12
# 4 2010-12-01 08:26:00       3.39  United Kingdom  2010     12

# %%
df['TotalSales'] = df['Quantity'] * df['UnitPrice']

# %%
total_sales_all_years = df['TotalSales'].sum()
sales_per_year = df.groupby('Year')['TotalSales'].sum().sort_values(ascending=False)
sales_per_month = df.groupby('Month')['TotalSales'].sum().sort_values(ascending=False)
print("TOTAL SALES OF ALL YEARS: \n", total_sales_all_years)
print("")
print("Total Sales per Year:\n", sales_per_year)
print("")
print("\nTotal Sales per Month:\n", sales_per_month)
# Out:
# TOTAL SALES OF ALL YEARS:
#  9726006.953999998
#
# Total Sales per Year:
#  Year
# 2011    8979283.344
# 2010     746723.610
# Name: TotalSales, dtype: float64
#
#
# Total Sales per Month:
#  Month
# 11    1456145.800
# 12    1179424.670
# 10    1069368.230
# 9     1017596.682
# 5      722094.100
# 6      689977.230
# 3      682013.980
# 8      681386.460
# 7      680156.991
# 1      558448.560
# 2      497026.410
# 4      492367.841
# Name: TotalSales, dtype: float64

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice         Country  Year  Month  TotalSales
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
if 'InvoiceDate' in df.columns:
    df = df.drop('InvoiceDate', axis=1)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#         UnitPrice         Country  Year  Month  TotalSales
# ...

# %%
country_to_continent = {
    'United Kingdom': 'Europe',
    'Germany': 'Europe',
    'France': 'Europe',
    'EIRE': 'Europe',
    'Spain': 'Europe',
    'Netherlands': 'Europe',
    'Belgium': 'Europe',
    'Switzerland': 'Europe',
    'Portugal': 'Europe',
    'Australia': 'Other',
    'Norway': 'Europe',
    'Italy': 'Europe',
    'Channel Islands': 'Europe',
    'Finland': 'Europe',
    'Cyprus': 'Europe',
    'Sweden': 'Europe',
    'Austria': 'Europe',
    'Denmark': 'Europe',
    'Japan': 'Other',
    'Poland': 'Europe',
    'Palestine': 'Other',  # Replaced Israel with Palestine
    'USA': 'Other',
    'Hong Kong': 'Other',
    'Singapore': 'Other',
    'Iceland': 'Europe',
    'Canada': 'Other',
    'Greece': 'Europe',
    'Malta': 'Europe',
    'United Arab Emirates': 'Other',
    'European Community': 'Europe',
    'RSA': 'Other',
    'Lebanon': 'Other',
    'Lithuania': 'Europe',
    'Brazil': 'Other',
    'Czech Republic': 'Europe',
    'Bahrain': 'Other',
    'Saudi Arabia': 'Other'
}
df = df[df['Country'] != 'Unspecified']

df['Continent'] = df['Country'].map(country_to_continent)

# %%
df = df.drop('Country',axis=1)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#         UnitPrice  Year  Month  TotalSales Continent
# ...

# %%
cat_col2 = df.select_dtypes(include=["object"]).columns.tolist()
print(cat_col2)
# Out:
# ['InvoiceNo', 'StockCode', 'Description', 'Continent']

# %%
df= df.drop('Description',axis=1)
df= df.drop('StockCode',axis=1)
df= df.drop('InvoiceNo',axis=1)

# %%
df
# Out:
#         Quantity  UnitPrice  Year  Month  TotalSales Continent
# 0              6       2.55  2010     12       15.30    Europe
# 1              6       3.39  2010     12       20.34    Europe
# 2              8       2.75  2010     12       22.00    Europe
# 3              6       3.39  2010     12       20.34    Europe
# 4              6       3.39  2010     12       20.34    Europe
# ...          ...        ...   ...    ...         ...       ...
# 541904        12       0.85  2011     12       10.20    Europe
# 541905         6       2.10  2011     12       12.60    Europe
# 541906         4       4.15  2011     12       16.60    Europe
# 541907         4       4.15  2011     12       16.60    Europe
# 541908         3       4.95  2011     12       14.85    Europe
#
# [536199 rows x 6 columns]

# %%
df['Continent'].value_counts(normalize=True) * 100
# Out:
# Continent
# Europe    99.47696
# Other      0.52304
# Name: proportion, dtype: float64

# %%
df = pd.get_dummies(df, columns= ['Continent'])

# %%
df['Continent_Europe'] = df['Continent_Europe'].astype(int)
df['Continent_Other'] = df['Continent_Other'].astype(int)

# %%
df
# Out:
#         Quantity  UnitPrice  Year  Month  TotalSales  Continent_Europe  \
# 0              6       2.55  2010     12       15.30                 1
# 1              6       3.39  2010     12       20.34                 1
# 2              8       2.75  2010     12       22.00                 1
# 3              6       3.39  2010     12       20.34                 1
# 4              6       3.39  2010     12       20.34                 1
# ...          ...        ...   ...    ...         ...               ...
# 541904        12       0.85  2011     12       10.20                 1
# 541905         6       2.10  2011     12       12.60                 1
# 541906         4       4.15  2011     12       16.60                 1
# 541907         4       4.15  2011     12       16.60                 1
# 541908         3       4.95  2011     12       14.85                 1
#
#         Continent_Other
# 0                     0
# 1                     0
# 2                     0
# ...

# %% [markdown]
# ### ---------------------------------------------------------------------------------------------------------------------------------- ###

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = df.drop(['TotalSales'],axis=1)
y = df['TotalSales']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3)

print('X_train shape: ', X_train.shape)
print('y_train shape: ', y_train.shape)
print('X_test shape: ', X_test.shape)
print('y_test shape: ', y_test.shape)
# Out:
# X_train shape:  (375339, 6)
# y_train shape:  (375339,)
# X_test shape:  (160860, 6)
# y_test shape:  (160860,)

# %%
# !pip install tensorflow

# %%
import tensorflow as tf

# %%
from tensorflow.keras import layers, models, callbacks, optimizers
from tensorflow.keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler

# Normalize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define the model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(layers.Dropout(0.3))  # Dropout layer
model.add(Dense(64, activation='relu'))
model.add(layers.BatchNormalization())  # Batch normalization
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64)                  │             256 │
# ...

# %%
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Normalize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

# Train the model
model.fit(X_train_scaled, y_train, validation_data=(X_test_scaled, y_test), epochs=50, batch_size=64, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/50
# 5865/5865 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 130612.7812 - val_loss: 24974.2148 - learning_rate: 0.0010
# Epoch 2/50
# 5865/5865 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - loss: 68472.1562 - val_loss: 36835.5234 - learning_rate: 0.0010
# Epoch 3/50
# 5865/5865 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 54972.7656 - val_loss: 136054.8906 - learning_rate: 0.0010
# Epoch 4/50
# 5865/5865 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 60206.3984 - val_loss: 73541.9141 - learning_rate: 0.0010
# Epoch 5/50
# 5865/5865 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - loss: 160511.5156 - val_loss: 10300.9385 - learning_rate: 0.0010
# Epoch 6/50
# 5865/5865 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 109947.7656 - val_loss: 27629.3223 - learning_rate: 0.0010
# Epoch 7/50
# 5865/5865 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 183096.3281 - val_loss: 77888.5547 - learning_rate: 0.0010
# Epoch 8/50
# ...

# %%
preds = model.predict(X_test).reshape(-1,)
res = pd.DataFrame()
res['Actual'] = y_test.values
res['Preds'] = preds
res
# Out:
# 5027/5027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
#         Actual      Preds
# 0        17.40  13.537364
# 1        12.60  12.621474
# 2         4.89  10.299846
# 3         3.29  12.676679
# 4         2.95  10.584121
# ...        ...        ...
# 160855   15.00  12.244151
# 160856   17.70  14.700578
# 160857    8.50  12.034956
# 160858   10.50  16.279753
# 160859   49.92  33.112705
#
# [160860 rows x 2 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Normalize the features (X)
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X)

# Use K-Means clustering to cluster the normalized features into distinct market segments
kmeans = KMeans(n_clusters=3, random_state=42)  # Choose the number of segments (clusters)
clusters = kmeans.fit_predict(X_normalized)

# Add the clusters to the original DataFrame and analyze the characteristics of each segment
df['Segment'] = clusters

# Analyze the resulting segments
segment_analysis = df.groupby('Segment').mean()

print(segment_analysis)
# Out:
#           Quantity  UnitPrice         Year      Month  TotalSales  \
# Segment
# 0         9.557711   4.358392  2011.000000   7.172052   17.942852
# 1        44.599358  15.956268  2010.964324   6.361755   72.493029
# 2         8.033188   7.113807  2010.000024  11.999857   16.687484
#
#          Continent_Europe  Continent_Other
# Segment
# 0                0.999406              0.0
# 1                0.000000              1.0
# 2                0.999952              0.0

# %% [markdown]
# ### Segment 0 (Average Buyers in Europe):
#
# Marketing Strategy: Focus on maintaining customer loyalty with discounts and loyalty programs.
# Product Development: Offer products that meet the standard expectations and preferences of European customers.
# Business Strategy: Enhance customer service and after-sales support to retain these customers.
#
#
# ### Segment 1 (High-Spenders in Other Continents):
#
# Marketing Strategy: Use premium marketing strategies, such as personalized offers and exclusive deals.
# Product Development: Develop high-end products with premium features and quality.
# Business Strategy: Invest in targeted advertising campaigns and partnerships with influencers to attract more high-spenders.
#
#
# ### Segment 2 (Occasional Buyers in Europe):
#
# Marketing Strategy: Increase engagement through seasonal promotions and targeted advertising.
# Product Development: Offer products that cater to occasional needs and unique demands.
# Business Strategy: Create awareness campaigns to convert occasional buyers into regular customers. */

# %% [markdown]
# ## Documentation:
#
# 1. Choice of Dataset
# The dataset used for this project includes various features such as Quantity, UnitPrice, and i couldn't use describtion ,but country i make groubing  (Continent_Europe, Continent_Other) and i made total sales. alos, date i made it column for year and month
#
# 2. Exploratory Data Analysis (EDA)
# Dataset Overview: Initial examination of the dataset to understand the structure and distribution of features.
# Descriptive Statistics: Calculation of mean, median, and standard deviation for numerical features.
# Correlation Analysis: Checking correlations between features to identify significant relationships.
# 3. Data Preprocessing
# Feature Selection: The 'TotalSales' column was selected as the target variable for the model.
# Data Splitting: The dataset was split into training and testing sets using an 80-20 ratio.
# Scaling: Features were scaled using StandardScaler to normalize the data, which is important for neural network performance.
# 4. Neural Network Development
# Model Architecture:
# Input Layer: Size matching the number of features.
# Hidden Layers: Three dense layers with 128, 64, and 32 neurons respectively, using ReLU activation.
# Output Layer: A single neuron with linear activation for regression.
# Additional Layers: Dropout and Batch Normalization to improve generalization and stability.
# Compilation: The model was compiled using the Adam optimizer and mean squared error (MSE) as the loss function.
# Training: The model was trained for 50 epochs with early stopping and learning rate reduction callbacks to prevent overfitting and improve convergence.
# 6. Model Evaluation
# Metrics: The model's performance was evaluated using MSE on the validation set.
# Performance: The final model showed better prediction accuracy compared to earlier attempts with consistent loss reduction.
# 7. Market Segmentation
# Predictions: The trained model was used to predict 'TotalSales' for the entire dataset.
# Clustering: K-Means clustering was applied to the predictions to segment the market into distinct groups.
# Segment Analysis: Each segment was analyzed to understand the characteristics, leading to insights on customer behavior and preferences.
# 8. Insights and Recommendations
# Segment Characteristics:
# Segment 0: Average buyers with moderate spending.
# Segment 1: High-value buyers with significantly higher spending.
# Segment 2: Lower spending, likely casual buyers.
